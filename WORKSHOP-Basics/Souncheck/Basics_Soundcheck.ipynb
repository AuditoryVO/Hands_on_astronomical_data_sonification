# %% [markdown]
# Sonification Workshop-Adrián García Riber-2026

# %%
import time
from pythonosc import udp_client

# %%
play = 1

# %%
duration = 4
interval = 1

# %%
while play==1:       
    client_s = udp_client.SimpleUDPClient("127.0.0.1", 9989)
    client_s.send_message("/s", 1)

    client0 = udp_client.SimpleUDPClient("127.0.0.1", 9990)   
    client0.send_message("/0", 110)
    time.sleep(interval)
    client0.send_message("/0", 0)

    
    client1 = udp_client.SimpleUDPClient("127.0.0.1", 9991) 
    client1.send_message("/1", 220)
    time.sleep(interval)
    client1.send_message("/1", 0)

    client2 = udp_client.SimpleUDPClient("127.0.0.1", 9992) 
    client2.send_message("/2", 440)
    time.sleep(interval)
    client2.send_message("/2", 0)
    
    client3 = udp_client.SimpleUDPClient("127.0.0.1", 9993) 
    client3.send_message("/3", 880)
    time.sleep(interval)
    client3.send_message("/3", 0)
    
    client4 = udp_client.SimpleUDPClient("127.0.0.1", 9994) 
    client4.send_message("/4", 110)
    time.sleep(interval)
    client4.send_message("/4", 0)
    
    client5 = udp_client.SimpleUDPClient("127.0.0.1", 9995) 
    client5.send_message("/5", 330)
    time.sleep(interval)
    client5.send_message("/5", 0)
    
    client6 = udp_client.SimpleUDPClient("127.0.0.1", 9996) 
    client6.send_message("/6", 660)
    time.sleep(interval)
    client6.send_message("/6", 0)
    
    client7 = udp_client.SimpleUDPClient("127.0.0.1", 9997) 
    client7.send_message("/7", 550)
    time.sleep(interval)
    client7.send_message("/7", 0)
    
    client8 = udp_client.SimpleUDPClient("127.0.0.1", 9998) 
    client8.send_message("/8", 1100)
    time.sleep(interval)
    client8.send_message("/8", 0)
    
    client9 = udp_client.SimpleUDPClient("127.0.0.1", 9999) 
    client9.send_message("/9", 2200)
    time.sleep(interval)
    client9.send_message("/9", 0)
    
    client10 = udp_client.SimpleUDPClient("127.0.0.1", 9980) 
    client10.send_message("/10", 1100)
    time.sleep(interval)
    client10.send_message("/10", 0)
    
    client11 = udp_client.SimpleUDPClient("127.0.0.1", 9981) 
    client11.send_message("/11", 880)
    time.sleep(interval)
    client11.send_message("/11", 0)
    
    client_s.send_message("/s", 0)
