# %% [markdown]
# Sonification Workshop-Adrián García Riber-2026

# %% [markdown]
# ## Project 1. Sonification of stars. The Tycho-2 Spectral Type Catalog
#
# About stars: https://science.nasa.gov/universe/stars/types/
# The Tycho-2 Spectral catalog: https://iopscience.iop.org/article/10.1086/345511
#
# Design and develop a sonification project to represent the Tycho-2 Spectral Type Catalog (Wright+, 2003). You can implement your own synthesizers and/or use any virtual instrument. You can also choose to control them by MIDI or OSC (MIDI recommended). In the following steps you have a mapping strategy proposal but you can design your own approach.
#
# - Use Aladin Sky Atlas to obtain the data from the Tycho-2 Spectral Type Catalog.
# - Export the table to a .txt file and clean the data.
# - Map the effective temperature (Teff) to the pitch or fundamental frequency of each note.
# - Map the magnitude (VTmag) to the amplitude of each sound or note.
# - Map each spectral type (OBAFGKM) to a musical instrument or synthesizer.
# - Explore the catalog sequentially. Represent all objects with the same duration, set it to allow the location of the sounds.

# %% [markdown]
# 1. Import the dependencies

# %% [markdown]
# 2. Load the table "Tycho-2_CDS-III-231-catalog.txt" as a pandas dataframe. You may need to clean the dataset.

# %% [markdown]
# 3. Extract the columns for the representation (Teff, VTmag, SpType, RAJ2000 and DEJ2000)

# %% [markdown]
# 4. Convert to numpy arrays all numerical lists

# %% [markdown]
# 5. Extract the first letter of each spectral type and save it in a list called "Type_ok".

# %% [markdown]
# 6. Normalize the variables to adapt the maximum and minimum values to the desired ranges

# %% [markdown]
# 7. Create a loop to send the MIDI messages. Send each spectral type to a different MIDI channel.

# %% [markdown]
# 8. Generate the sonification with your own Synth or DAW
